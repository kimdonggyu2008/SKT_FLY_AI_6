# %% [markdown]
# <a href="https://colab.research.google.com/github/kimdonggyu2008/SKT_FLY_AI_6/blob/main/controlnet_%ED%85%8C%EC%8A%A4%ED%8A%B8.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/lllyasviel/ControlNet.git
# Out:
# Cloning into 'ControlNet'...
# remote: Enumerating objects: 1356, done.
# remote: Total 1356 (delta 0), reused 0 (delta 0), pack-reused 1356 (from 1)
# Receiving objects: 100% (1356/1356), 122.40 MiB | 20.78 MiB/s, done.
# Resolving deltas: 100% (599/599), done.

# %%
# !wget -O /content/ControlNet/models/control_sd15_seg.pth "https://huggingface.co/lllyasviel/ControlNet/resolve/main/models/control_sd15_seg.pth"
# Out:
# --2025-02-03 06:02:45--  https://huggingface.co/lllyasviel/ControlNet/resolve/main/models/control_sd15_seg.pth
# Resolving huggingface.co (huggingface.co)... 18.164.174.17, 18.164.174.55, 18.164.174.118, ...
# Connecting to huggingface.co (huggingface.co)|18.164.174.17|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# ...

# %%
# !pip install -q condacolab
import condacolab
condacolab.install()
# Out:
# ⏬ Downloading https://github.com/jaimergp/miniforge/releases/download/24.11.2-1_colab/Miniforge3-colab-24.11.2-1_colab-Linux-x86_64.sh...
# 📦 Installing...
# 📌 Adjusting configuration...
# 🩹 Patching environment...
# ⏲ Done in 0:00:12
# 🔁 Restarting kernel...

# %%
# !conda env create -f /content/ControlNet/environment.yaml
# Out:
# Channels:
#  - pytorch
#  - defaults
#  - conda-forge
# Platform: linux-64
# done
# done
#
#
# ==> WARNING: A newer version of conda exists. <==
#     current version: 24.11.2
#     latest version: 25.1.1
#
# Please update conda by running
#
#     $ conda update -n base -c conda-forge conda
#
#
#
# ...
# pytorch-1.12.1       | 1.19 GB   | :   0% 0/1 [00:00<?, ?it/s]
# cudatoolkit-11.3.1   | 549.3 MB  | :   0% 0/1 [00:00<?, ?it/s]
#
# mkl-2021.4.0         | 142.6 MB  | :   0% 0/1 [00:00<?, ?it/s]
#
#
# python-3.8.5         | 49.3 MB   | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
# torchvision-0.13.1   | 28.7 MB   | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
# ffmpeg-4.3           | 9.9 MB    | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
#
# numpy-base-1.23.1    | 5.6 MB    | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
# libgcc-ng-11.2.0     | 5.3 MB    | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
#
# libstdcxx-ng-11.2.0  | 4.7 MB    | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
# ...

# %%
# !chmod +x /content/ControlNet/gradio_seg2image.py

# %%
# !conda run -n control python --version  # 환경 이름 확인 후 실행
# Out:
# Python 3.8.5

# %%
cd /content/ControlNet
# Out:
# /content/ControlNet

# %%
# !conda run -n control python /content/ControlNet/gradio_seg2image.py
# Out:
# 사람모양
# 개
# 고양이
# 사람같이 생긴 고양이
#
# CondaError: KeyboardInterrupt
